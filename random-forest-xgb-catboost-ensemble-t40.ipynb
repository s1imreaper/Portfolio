# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier

# %%
train_path = "/kaggle/input/playground-series-s3e12/train.csv"
test_path = "/kaggle/input/playground-series-s3e12/test.csv"
sub_path = "/kaggle/input/playground-series-s3e12/sample_submission.csv"
df_train = pd.read_csv(train_path)
df_test = pd.read_csv(test_path)
df_sub = pd.read_csv(sub_path)

# %%
df_train.head(3)
# Out:
#    id  gravity    ph  osmo  cond  urea  calc  target
# 0   0    1.013  6.19   443  14.8   124  1.45       0
# 1   1    1.025  5.40   703  23.6   394  4.18       0
# 2   2    1.009  6.13   371  24.5   159  9.04       0

# %%
df_test.head(3)
# Out:
#     id  gravity    ph  osmo  cond  urea   calc
# 0  414    1.017  5.24   345  11.5   152   1.16
# 1  415    1.020  5.68   874  29.0   385   3.46
# 2  416    1.024  5.36   698  19.5   354  13.00

# %%
df_train.drop("id", inplace = True, axis = 1)
df_test.drop("id", inplace = True, axis = 1)

# %%
new_list = list(set(df_train.index.tolist()) - set(df_train[df_train["urea"] < 15].index.tolist()))
df_train = df_train.loc[new_list,]

# %%
s_temp = df_train["target"].copy()
df_train.drop("target", axis = 1, inplace = True)
df_train["train"], df_test["train"] = 1, 0
df_train["target"] = s_temp.copy()
df = pd.concat([df_train, df_test])

# %% [markdown]
# ### Feature Generation

# %%
df["gravity/ph"] = df["gravity"] / df["ph"]
df["osmo/cond"] = df["osmo"] / df["cond"]
df["gravity*ph"] = df["gravity"] * df["ph"]
df["gravity*osmo"] = df["gravity"] * df["osmo"]
df["osmo*urea"] = df["osmo"] * df["urea"]
df["cond_urea_ph"] = df["cond"] * df["urea"] / df["ph"]
df["ph*osmo"] = df["ph"] * df["osmo"]
df["cond*calc"] = df["cond"] * df["calc"]
df["gravity/calc"] = df["gravity"] / df["calc"]

# %% [markdown]
# ### Normalizing Data

# %%
columns = df.columns.tolist()
columns.remove("train")
columns.remove("target")

# %%
data_norm = preprocessing.normalize(df[columns], axis=0)
df_norm = pd.DataFrame(data_norm, columns = columns)

# %%
df_norm.reset_index(drop = True, inplace = True)
df.reset_index(drop = True, inplace = True)

# %%
df_norm["train"], df_norm["target"] = df["train"], df["target"]

# %% [markdown]
# ### Setting Variables for Learning

# %%
features = ['gravity/ph', 'osmo/cond', 'gravity*ph', 'gravity*osmo', 'osmo*urea',
            'cond_urea_ph', 'ph*osmo', 'cond*calc', 'gravity/calc']

# %%
X = df_norm[df_norm["train"] == 1][features].copy()
y = df_norm[df_norm["train"] == 1]["target"].copy()
print(X.shape, y.shape)
# Out:
# (412, 9) (412,)

# %%
df_norm
# Out:
#       gravity        ph      osmo      cond      urea      calc  gravity/ph  \
# 0    0.037934  0.039449  0.024310  0.024651  0.015191  0.010662    0.035910
# 1    0.038383  0.034414  0.038578  0.039309  0.048269  0.030736    0.041651
# 2    0.037784  0.039067  0.020359  0.040808  0.019479  0.066472    0.036118
# 3    0.038233  0.031291  0.024255  0.034645  0.048759  0.048751    0.045629
# 4    0.038233  0.035243  0.047962  0.029648  0.047166  0.016250    0.040513
# ..        ...       ...       ...       ...       ...       ...         ...
# 683  0.038533  0.039959  0.046809  0.035645  0.044593  0.053751    0.036012
# 684  0.037896  0.035816  0.022499  0.023319  0.023889  0.010662    0.039513
# 685  0.038608  0.036199  0.047962  0.048303  0.046553  0.033016    0.039830
# 686  0.038158  0.034860  0.029798  0.035645  0.020827  0.012059    0.040877
# 687  0.038083  0.039449  0.038304  0.048303  0.030872  0.025957    0.036052
#
#      osmo/cond  gravity*ph  gravity*osmo  osmo*urea  cond_urea_ph   ph*osmo  \
# 0     0.034258    0.039267      0.024119   0.007977      0.008174  0.025676
# 1     0.034093    0.034661      0.038728   0.040224      0.047475  0.035545
# 2     0.017331    0.038733      0.020119   0.008567      0.017521  0.021294
# 3     0.024321    0.031393      0.024254   0.025547      0.046485  0.020321
# 4     0.056197    0.035357      0.047960   0.048866      0.034167  0.045255
# ..         ...         ...           ...        ...           ...       ...
# 683   0.045620    0.040403      0.047175   0.045091      0.034253  0.050078
# 684   0.033518    0.035616      0.022300   0.011611      0.013393  0.021575
# 685   0.034494    0.036672      0.048430   0.048232      0.053491  0.046483
# 686   0.029041    0.034905      0.029738   0.013406      0.018337  0.027811
# 687   0.027547    0.039422      0.038152   0.025544      0.032551  0.040456
#
#      cond*calc  gravity/calc  train  target
# 0     0.006233      0.033203      1     0.0
# 1     0.028652      0.011654      1     0.0
# 2     0.064328      0.005305      1     0.0
# 3     0.040054      0.007319      1     1.0
# 4     0.011426      0.021957      1     1.0
# ..         ...           ...    ...     ...
# 683   0.045436      0.006690      0     NaN
# 684   0.005896      0.033170      0     NaN
# 685   0.037819      0.010913      0     NaN
# 686   0.010194      0.029530      0     NaN
# 687   0.029733      0.013692      0     NaN
#
# [688 rows x 17 columns]

# %%
alldt = df_norm.copy()
alldt2 = alldt.copy()
alldt = alldt.iloc[:, :-1]
alldt
# Out:
#       gravity        ph      osmo      cond      urea      calc  gravity/ph  \
# 0    0.037934  0.039449  0.024310  0.024651  0.015191  0.010662    0.035910
# 1    0.038383  0.034414  0.038578  0.039309  0.048269  0.030736    0.041651
# 2    0.037784  0.039067  0.020359  0.040808  0.019479  0.066472    0.036118
# 3    0.038233  0.031291  0.024255  0.034645  0.048759  0.048751    0.045629
# 4    0.038233  0.035243  0.047962  0.029648  0.047166  0.016250    0.040513
# ..        ...       ...       ...       ...       ...       ...         ...
# 683  0.038533  0.039959  0.046809  0.035645  0.044593  0.053751    0.036012
# 684  0.037896  0.035816  0.022499  0.023319  0.023889  0.010662    0.039513
# 685  0.038608  0.036199  0.047962  0.048303  0.046553  0.033016    0.039830
# 686  0.038158  0.034860  0.029798  0.035645  0.020827  0.012059    0.040877
# 687  0.038083  0.039449  0.038304  0.048303  0.030872  0.025957    0.036052
#
#      osmo/cond  gravity*ph  gravity*osmo  osmo*urea  cond_urea_ph   ph*osmo  \
# 0     0.034258    0.039267      0.024119   0.007977      0.008174  0.025676
# 1     0.034093    0.034661      0.038728   0.040224      0.047475  0.035545
# 2     0.017331    0.038733      0.020119   0.008567      0.017521  0.021294
# 3     0.024321    0.031393      0.024254   0.025547      0.046485  0.020321
# 4     0.056197    0.035357      0.047960   0.048866      0.034167  0.045255
# ..         ...         ...           ...        ...           ...       ...
# 683   0.045620    0.040403      0.047175   0.045091      0.034253  0.050078
# 684   0.033518    0.035616      0.022300   0.011611      0.013393  0.021575
# 685   0.034494    0.036672      0.048430   0.048232      0.053491  0.046483
# 686   0.029041    0.034905      0.029738   0.013406      0.018337  0.027811
# 687   0.027547    0.039422      0.038152   0.025544      0.032551  0.040456
#
#      cond*calc  gravity/calc  train
# 0     0.006233      0.033203      1
# 1     0.028652      0.011654      1
# 2     0.064328      0.005305      1
# 3     0.040054      0.007319      1
# 4     0.011426      0.021957      1
# ..         ...           ...    ...
# 683   0.045436      0.006690      0
# 684   0.005896      0.033170      0
# 685   0.037819      0.010913      0
# 686   0.010194      0.029530      0
# 687   0.029733      0.013692      0
#
# [688 rows x 16 columns]

# %%
X = alldt[alldt["train"] == 1].copy()
y = alldt2[alldt2["train"] == 1]["target"].copy()
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3, random_state = 121)
X_train, y_train = X, y

xbc_model = XGBClassifier(n_estimators = 140, learning_rate = 0.05, max_depth = 4,
                          eval_metric = "auc", booster = 'gbtree')
xbc_model.fit(X_train, y_train)

rfc_model = RandomForestClassifier(n_estimators = 140, max_depth = 4)
rfc_model.fit(X_train, y_train)

cbc = CatBoostClassifier(learning_rate=0.05, n_estimators=140)
cbc.fit(X_train, y_train)


rfc_preds = rfc_model.predict_proba(X_val)[:, 1]
xgb_preds = xbc_model.predict_proba(X_val)[:, 1]
cbc_preds = cbc.predict_proba(X_val)[:, 1]


ensemble_preds = (cbc_preds + rfc_preds + xgb_preds)/ 3

ensemble_score = roc_auc_score(y_val, ensemble_preds)
print("ROC AUC Score:", ensemble_score)
# Out:
# 0:	learn: 0.6830768	total: 1.81ms	remaining: 252ms
# 1:	learn: 0.6738375	total: 3.92ms	remaining: 270ms
# 2:	learn: 0.6636508	total: 5.44ms	remaining: 248ms
# 3:	learn: 0.6532405	total: 6.92ms	remaining: 235ms
# 4:	learn: 0.6449345	total: 8.41ms	remaining: 227ms
# 5:	learn: 0.6362487	total: 9.98ms	remaining: 223ms
# 6:	learn: 0.6277742	total: 11.5ms	remaining: 218ms
# 7:	learn: 0.6198903	total: 13ms	remaining: 214ms
# 8:	learn: 0.6117229	total: 14.5ms	remaining: 211ms
# 9:	learn: 0.6053308	total: 16.2ms	remaining: 210ms
# 10:	learn: 0.5976859	total: 17.8ms	remaining: 208ms
# 11:	learn: 0.5920583	total: 19.3ms	remaining: 205ms
# 12:	learn: 0.5869130	total: 20.7ms	remaining: 203ms
# 13:	learn: 0.5812771	total: 22.4ms	remaining: 202ms
# 14:	learn: 0.5768337	total: 24ms	remaining: 200ms
# 15:	learn: 0.5718005	total: 25.5ms	remaining: 197ms
# 16:	learn: 0.5656538	total: 27.1ms	remaining: 196ms
# 17:	learn: 0.5618459	total: 28.6ms	remaining: 194ms
# 18:	learn: 0.5585692	total: 30.3ms	remaining: 193ms
# 19:	learn: 0.5548944	total: 31.9ms	remaining: 191ms
# 20:	learn: 0.5502804	total: 33.5ms	remaining: 190ms
# 21:	learn: 0.5460605	total: 35.2ms	remaining: 189ms
# 22:	learn: 0.5423147	total: 36.8ms	remaining: 187ms
# 23:	learn: 0.5394474	total: 38.4ms	remaining: 186ms
# 24:	learn: 0.5366478	total: 39.9ms	remaining: 184ms
# 25:	learn: 0.5333160	total: 41.5ms	remaining: 182ms
# 26:	learn: 0.5306405	total: 43ms	remaining: 180ms
# 27:	learn: 0.5281113	total: 44.6ms	remaining: 179ms
# 28:	learn: 0.5256188	total: 46.1ms	remaining: 177ms
# 29:	learn: 0.5228694	total: 47.7ms	remaining: 175ms
# 30:	learn: 0.5203733	total: 49.5ms	remaining: 174ms
# 31:	learn: 0.5180416	total: 51.1ms	remaining: 172ms
# 32:	learn: 0.5152536	total: 53ms	remaining: 172ms
# 33:	learn: 0.5124101	total: 54.7ms	remaining: 171ms
# 34:	learn: 0.5100546	total: 56.7ms	remaining: 170ms
# 35:	learn: 0.5079225	total: 58.5ms	remaining: 169ms
# 36:	learn: 0.5056383	total: 60.1ms	remaining: 167ms
# 37:	learn: 0.5041252	total: 61.7ms	remaining: 166ms
# 38:	learn: 0.5022064	total: 63.3ms	remaining: 164ms
# 39:	learn: 0.4998872	total: 64.9ms	remaining: 162ms
# 40:	learn: 0.4980579	total: 66.4ms	remaining: 160ms
# 41:	learn: 0.4958906	total: 68ms	remaining: 159ms
# 42:	learn: 0.4941031	total: 69.6ms	remaining: 157ms
# 43:	learn: 0.4921597	total: 71.1ms	remaining: 155ms
# 44:	learn: 0.4905658	total: 72.6ms	remaining: 153ms
# 45:	learn: 0.4890572	total: 74.2ms	remaining: 152ms
# 46:	learn: 0.4867338	total: 75.7ms	remaining: 150ms
# 47:	learn: 0.4850168	total: 77.7ms	remaining: 149ms
# 48:	learn: 0.4834446	total: 79.3ms	remaining: 147ms
# 49:	learn: 0.4815825	total: 80.7ms	remaining: 145ms
# 50:	learn: 0.4799305	total: 82.2ms	remaining: 143ms
# 51:	learn: 0.4784872	total: 83.8ms	remaining: 142ms
# 52:	learn: 0.4768081	total: 85.3ms	remaining: 140ms
# 53:	learn: 0.4758364	total: 86.8ms	remaining: 138ms
# 54:	learn: 0.4747666	total: 88.3ms	remaining: 136ms
# 55:	learn: 0.4740228	total: 89.8ms	remaining: 135ms
# 56:	learn: 0.4727608	total: 91.4ms	remaining: 133ms
# 57:	learn: 0.4716038	total: 92.9ms	remaining: 131ms
# 58:	learn: 0.4704481	total: 94.4ms	remaining: 130ms
# 59:	learn: 0.4693151	total: 96ms	remaining: 128ms
# 60:	learn: 0.4680032	total: 97.5ms	remaining: 126ms
# 61:	learn: 0.4663711	total: 99.1ms	remaining: 125ms
# 62:	learn: 0.4651243	total: 101ms	remaining: 123ms
# 63:	learn: 0.4639052	total: 102ms	remaining: 121ms
# 64:	learn: 0.4629837	total: 104ms	remaining: 120ms
# 65:	learn: 0.4613806	total: 105ms	remaining: 118ms
# 66:	learn: 0.4601714	total: 107ms	remaining: 117ms
# 67:	learn: 0.4594600	total: 109ms	remaining: 115ms
# 68:	learn: 0.4587531	total: 110ms	remaining: 114ms
# 69:	learn: 0.4576243	total: 112ms	remaining: 112ms
# 70:	learn: 0.4564256	total: 114ms	remaining: 110ms
# 71:	learn: 0.4548735	total: 115ms	remaining: 109ms
# 72:	learn: 0.4540530	total: 117ms	remaining: 107ms
# 73:	learn: 0.4532530	total: 119ms	remaining: 106ms
# 74:	learn: 0.4524062	total: 120ms	remaining: 104ms
# 75:	learn: 0.4510760	total: 122ms	remaining: 103ms
# 76:	learn: 0.4499602	total: 123ms	remaining: 101ms
# 77:	learn: 0.4481405	total: 125ms	remaining: 99.4ms
# 78:	learn: 0.4467542	total: 127ms	remaining: 98ms
# 79:	learn: 0.4453139	total: 130ms	remaining: 97.2ms
# 80:	learn: 0.4439659	total: 131ms	remaining: 95.6ms
# 81:	learn: 0.4428297	total: 133ms	remaining: 94ms
# 82:	learn: 0.4422236	total: 135ms	remaining: 92.4ms
# 83:	learn: 0.4414639	total: 136ms	remaining: 90.9ms
# 84:	learn: 0.4404419	total: 138ms	remaining: 89.2ms
# 85:	learn: 0.4397367	total: 140ms	remaining: 87.6ms
# 86:	learn: 0.4392390	total: 141ms	remaining: 85.9ms
# 87:	learn: 0.4383695	total: 143ms	remaining: 84.3ms
# 88:	learn: 0.4375519	total: 144ms	remaining: 82.7ms
# 89:	learn: 0.4362669	total: 146ms	remaining: 81.1ms
# 90:	learn: 0.4350469	total: 148ms	remaining: 79.5ms
# 91:	learn: 0.4344089	total: 149ms	remaining: 77.9ms
# 92:	learn: 0.4338087	total: 151ms	remaining: 76.2ms
# 93:	learn: 0.4332368	total: 153ms	remaining: 74.7ms
# 94:	learn: 0.4324648	total: 154ms	remaining: 73ms
# 95:	learn: 0.4316022	total: 156ms	remaining: 71.4ms
# 96:	learn: 0.4304410	total: 158ms	remaining: 69.9ms
# 97:	learn: 0.4292717	total: 159ms	remaining: 68.3ms
# 98:	learn: 0.4281685	total: 161ms	remaining: 66.7ms
# 99:	learn: 0.4276745	total: 163ms	remaining: 65ms
# 100:	learn: 0.4261889	total: 164ms	remaining: 63.4ms
# 101:	learn: 0.4254624	total: 166ms	remaining: 61.8ms
# 102:	learn: 0.4244494	total: 168ms	remaining: 60.2ms
# 103:	learn: 0.4237395	total: 169ms	remaining: 58.6ms
# 104:	learn: 0.4226369	total: 171ms	remaining: 57ms
# 105:	learn: 0.4220551	total: 173ms	remaining: 55.6ms
# 106:	learn: 0.4212592	total: 175ms	remaining: 54ms
# 107:	learn: 0.4203669	total: 177ms	remaining: 52.4ms
# 108:	learn: 0.4197049	total: 179ms	remaining: 50.9ms
# 109:	learn: 0.4187178	total: 181ms	remaining: 49.2ms
# 110:	learn: 0.4174959	total: 182ms	remaining: 47.6ms
# 111:	learn: 0.4162775	total: 184ms	remaining: 46ms
# 112:	learn: 0.4156473	total: 186ms	remaining: 44.4ms
# 113:	learn: 0.4148852	total: 188ms	remaining: 42.8ms
# 114:	learn: 0.4138361	total: 190ms	remaining: 41.3ms
# 115:	learn: 0.4125311	total: 192ms	remaining: 39.7ms
# 116:	learn: 0.4120741	total: 194ms	remaining: 38.1ms
# 117:	learn: 0.4108553	total: 195ms	remaining: 36.4ms
# 118:	learn: 0.4094651	total: 197ms	remaining: 34.8ms
# 119:	learn: 0.4083946	total: 199ms	remaining: 33.1ms
# 120:	learn: 0.4077811	total: 200ms	remaining: 31.5ms
# 121:	learn: 0.4070463	total: 202ms	remaining: 29.8ms
# 122:	learn: 0.4065861	total: 204ms	remaining: 28.2ms
# 123:	learn: 0.4054274	total: 205ms	remaining: 26.5ms
# 124:	learn: 0.4040268	total: 207ms	remaining: 24.8ms
# 125:	learn: 0.4029208	total: 209ms	remaining: 23.2ms
# 126:	learn: 0.4018379	total: 210ms	remaining: 21.5ms
# 127:	learn: 0.4012625	total: 212ms	remaining: 19.9ms
# 128:	learn: 0.4006580	total: 213ms	remaining: 18.2ms
# 129:	learn: 0.3995883	total: 215ms	remaining: 16.6ms
# 130:	learn: 0.3985248	total: 217ms	remaining: 14.9ms
# 131:	learn: 0.3980800	total: 218ms	remaining: 13.2ms
# 132:	learn: 0.3971288	total: 220ms	remaining: 11.6ms
# 133:	learn: 0.3965738	total: 222ms	remaining: 9.93ms
# 134:	learn: 0.3959736	total: 223ms	remaining: 8.28ms
# 135:	learn: 0.3956185	total: 225ms	remaining: 6.62ms
# 136:	learn: 0.3952359	total: 227ms	remaining: 4.96ms
# 137:	learn: 0.3945361	total: 228ms	remaining: 3.31ms
# 138:	learn: 0.3941875	total: 230ms	remaining: 1.65ms
# 139:	learn: 0.3935938	total: 232ms	remaining: 0us
# ROC AUC Score: 0.9416077507200837

# %%
X_sub = alldt[alldt["train"] == 0].copy()
rfc_preds = rfc_model.predict_proba(X_sub)[:, 1]
xgb_preds = xbc_model.predict_proba(X_sub)[:, 1]
cbc_preds = cbc.predict_proba(X_sub)[:, 1]
ensemble_preds = (.2 * cbc_preds + .3 * rfc_preds + .5 * xgb_preds)
my_preds = pd.DataFrame(data = ensemble_preds)
df_sub["target"] = my_preds
df_sub
# Out:
#       id    target
# 0    414  0.292246
# 1    415  0.633379
# 2    416  0.851359
# 3    417  0.425788
# 4    418  0.293882
# ..   ...       ...
# 271  685  0.915767
# 272  686  0.105842
# 273  687  0.728704
# 274  688  0.106748
# 275  689  0.532870
#
# [276 rows x 2 columns]

# %%
df_sub.to_csv('submission_II.csv', index = False)
